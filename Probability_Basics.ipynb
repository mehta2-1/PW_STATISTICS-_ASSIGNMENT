# %% [markdown]
# #ASSIGNMENT : STATISTICS (PROBABILITY BASICS)
#
#
# #Q1 : A die is rolled. What is the probability of getting:
#
# (a) An even number
#
# (b) A number greater than 4
#
# #ANS:
#
# ## (a) total outcome on die = 6{1,2,3,4,5,6}
# ##     favourable outcome = 3{2,4,6}
# ##     total outcome of getting an even number = 1/2 ( i.e. 3/6)
#
#
# ##(b)  total outcome = 6 {1,2,3,4,5,6}
# ##     favourable outcome = 2 {5,6}
# ##     total outcome of getting a no. greater than 4 = 1/3 (i.e. 2/6)
#
#
#
#
# #Q2 : In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
#
#
# #ANS:
#
# ## P(MUS)= M + S - (M (INTERSECTION) S ) / TOTAL NO. OF STUDENTS
# ##       = 30/50 = 3/5
#
#
# #Q3 : A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability that the next ball is also red (without replacement)?
#
#
# #ANS:
# ## NO. OF BALLS BEFORE DRAWING A RED BALL ;
# ## TOTAL NO. OF BALLS = 5
# ## TOTAL NO. OF RED BALLS = 3
# ## TOTAL NO. OF BLUE BALLS = 2
# ## NO. OF BALLS AFTER DRAWING A RED BALL (WITHOUT REPLACEMENT)
# ## TOTAL NO. OF BALLS = 4
# ## FAVOURABLE OUTCOME OF GETTING RED = 2
# ## PROBABILITY OF GETTING A RED BALL = 1/2 (i.e. 2/4)
#
#
#
# #Q4 : The population of a school is divided into 60% boys and 40% girls. If you want equal representation of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling? Why?
#
#
# #ANS:
# ## we should go for 'SATISFIED SAMPLING' as population has groups & we know that this method of sampling ensures equal representation from each group.
#
#
# #Q5 : The average height of 1000 students = 160 cm. A sample of 100 students shows an average height = 158 cm. Find the sampling error.
#
#
# #ANS:
# ## POPULATION MEAN = 160 CM
# ## SAMPLE MEAN = 158 CM
# ## SAMPLIN ERROR = POPULATION MEAN - SAMPLE MEAN
# ##                = 160 - 158
# ##                = 2 CM
#
#
#
#
# #Q6.The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what is the standard error of the mean (SEM)?
#
# #ANS:
# ##σ = 5000
# ##n = 100
# ## SEM = σ/⌋n
# ##     = 500
#
#
# #Q7 :  In a group of 100 students:
#  40 like Cricket (C)
#
# 30 like Football (F)
#
# 10 like both Cricket and Football
#
# Find the probability that a student likes at least one sport.
#
# #ANS:
# ## P(CUF) = C + F - (C (INTERSACTION)F)/ TOTAL NO. OF STUDENTS
# ##        = 60/100 = 3/5
#
#
# #Q8 :  From a deck of 52 cards, two cards are drawn without replacement. What is the probability that both are Aces?
#
# #ANS:
# ## TOTAL CARDS = 52
# ## TOTAL ACES = 4
# ## P(1ST ACE) = 4/52
# ## P(2ND ACE i.e. AFTER ONE CARD IS DRAWN WITHOUT REPLACEMENT) =3/51
#
#
# #Q9 :  A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the probability that all are non-defective?
#
# #ANS:
# ## DEFECTIVE PERCENTAGE = 2%
# ## NON - DEFECTIVE PERCENTAGE = 98%
# ## P(NON DEFECTIVE BULBS) = (98%)^5
#
#
#
# #Q10 :  Differentiate between discrete and continuous random variables with examples .
#
# #ANS:
# ##DISCRETE RANDOM VARIABLE ;
# ## > TAKES COUNTABLE VALUE,
# ## > EXAMPLE = NO. OF STUDENTS , DICE OUTCOMES
#
# ##CONTINUOUS RANDOM VARIABLE ;
# ## > TAKES ANY VALUE IN A RANGE,
# ## > EXAMPLE = HEIGHT , WEIGHT , TIME
