# %% [markdown]
# #STATISTICS-
# #ASSIGNMENT - HYPOTHESIS TESTING
#
#
# #Q1 - What is a null hypothesis (H₀) and why is it important in hypothesis testing?
#
# #ANS-
# ## The null hypothesis is a statement that assumes no effect, no difference, or no relationship in the population.
# ##It is important as:
#
#
# 1. Provides a starting assumption.
# 2. Basis for statistical testing.
# 3. Helps determine whether observed data is due to chance.
#
#
# #Q2 -  What does the significance level (α) represent in hypothesis testing?
#
# #ANS-
# ##The significance level (α) is the probability of rejecting a true null hypothesis.
#
#
# #Q3 - Differentiate between Type I and Type II errors.
#
# #ANS-
# ## TYPE(I) ERROR : Rejecting a true 'NULL HYPOTHESIS' (False Positive)
# ## TYPE(II) ERROR : Failing to reject a false 'NULL HYPOTHESIS' (False Negative)
#
#
# #Q4 - Explain the difference between a one-tailed and two-tailed test. Give an example of each.
#
# #ANS-
# ## ONE TAILED TEST : Tests in one direction only.
# ## EX - μ > 10
#
# ## TWO TAILED TEST : Tests for difference in both directions.
# ## EX - μ ≠ 10
#
#
# #Q5 -  A company claims that the average time to resolve a customer complaint is 10 minutes. A random sample of 9 complaints gives an average time of 12 minutes and a standard deviation of 3 minutes. At α = 0.05, test the claim.
#
# #ANS -
# ## Given:
#
# μ₀ = 10
# x̄ = 12
# s = 3
# n = 9
# α = 0.05
# ## t= ̵̵x-𝛍o÷(s/⇃n)
# ## t= 12-10 ÷ (3⌋9)
# ## t= 2/ 1 = 2
# ## df = 8
# ## t(0.05, two-tailed) ≈ 2.306   ;  Since 2 < 2.306 → Fail to reject H₀
#
#
# #Q6 - When should you use a Z-test instead of a t-test?
#
# #ANS -
# ##When to use Z-test;
#
# Population standard deviation known
#
# Large sample (n ≥ 30)
#
# ##When to use t-test;
#
# Population SD unknown
#
# Small sample (n < 30)
#
#
# #Q7 - The productivity of 6 employees was measured before and after a training program. At α = 0.05, test if the training improved productivity .
#
# #ANS -
# ## Step 1: Differences
#
# 5, 5, 1, 3, 1, 3
#
# Mean difference: 𝑑ˉ=3
# ##Standard Deviation
#
# Variance: 𝑠2=3.2
#           𝑠=1.789
# ## Step 3: Test Statistic
#            𝑡=3/(1.789/⌋6)
#            t=4.11
# 	df = 5
#   Critical value (one-tailed) ≈ 2.015
#   4.11 > 2.015 → Reject H₀
#
#
#
# #Q8 - A company wants to test if product preference is independent of gender.At α = 0.05, test independence .
#
# #ANS -
# ## Step 1: Expected Values
#
# Male A = 20
# Male B = 30
# Female A = 20
# Female B = 30
# ##Step 2: Chi-square Statistic
#            𝜒2=16.66
#   df = 1
#   Critical value = 3.841
#   16.66 > 3.841 → Reject H₀
# ##Conclusion:
#     Product preference depends on gender.
